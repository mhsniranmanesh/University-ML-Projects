# %% [markdown]
# ---
#
#
# **Machine Learning**
#
# **Mohsen Iranmanesh**
#
# **98155002**
#
#
# ---

# %% [markdown]
# # Importing MNIST Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import keras

(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
X_train = X_train.astype(float) / 255.
X_test = X_test.astype(float) / 255.

X_train = X_train.reshape([X_train.shape[0], -1])
X_test = X_test.reshape([X_test.shape[0], -1])

plt.figure(figsize=[6,6])
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.title("Label: %i"%y_train[i])
    plt.imshow(X_train[i].reshape([28,28]),cmap='gray');

# %%
data = X_train[:15000]
labels = y_train[:15000]

print("The shape of sample data = ", data.shape)
print("The shape of sample labels = ", labels.shape)
# Out:
# The shape of sample data =  (15000, 784)
# The shape of sample labels =  (15000,)

# %% [markdown]
# # Data-preprocessing: Standardizing the data

# %%
from sklearn.preprocessing import StandardScaler
standardized_data = StandardScaler().fit_transform(data)
print(standardized_data.shape)
# Out:
# (15000, 784)

# %%
sample_data = standardized_data
covar_matrix = np.matmul(sample_data.T , sample_data)

# %% [markdown]
# # Finding eigen-values and eigen-vectors

# %%
from scipy.linalg import eigh 

values, vectors = eigh(covar_matrix, eigvals=(782,783))
print("Shape of eigen vectors = ",vectors.shape)
vectors = vectors.T
print("Updated shape of eigen vectors = ",vectors.shape)
# Out:
# Shape of eigen vectors =  (784, 2)
# Updated shape of eigen vectors =  (2, 784)

# %% [markdown]
# # Projecting the data

# %%
import matplotlib.pyplot as plt
import pandas as pd

new_coordinates = np.matmul(vectors, sample_data.T)
new_coordinates = np.vstack((new_coordinates, labels)).T
dataframe = pd.DataFrame(data=new_coordinates, columns=("1st", "2nd", "label"))
print(dataframe.head())
# Out:
#    1st_principal  2nd_principal  label
# 0      -4.457050       0.960769    5.0
# 1      -7.397795      -8.658155    0.0
# 2       9.640690      -2.082854    4.0
# 3      -3.356074       7.187465    1.0
# 4       2.979880       4.933889    9.0

# %% [markdown]
# # Plot the projected Data

# %%
import seaborn as sn

sn.FacetGrid(dataframe, hue="label", height=6).map(plt.scatter, '1st_principal', '2nd_principal').add_legend()
plt.show()

# %% [markdown]
# ---
#
#
# **As we saw, reducing the dimention to 2 is not capable of seperating the classes properly, and this is because PCA is performing the reduction based on just data variance in each class. The better way to do this dimension reduction can be performed by t-SNE which is based on the similarities. So we will first reduce the features from 784 to 50 with PCA and after that reduce the dimetion to 2 with the help of t-SNE**
#
#
# ---

# %% [markdown]
# # t-SNE

# %%
import numpy as np
import pandas as pd
import keras
import seaborn as sns
from scipy.spatial.distance import pdist, squareform
from scipy import linalg
from sklearn import decomposition
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import pairwise_distances
from sklearn.manifold.t_sne import _joint_probabilities
from matplotlib import pyplot as plt

sns.set(rc={'figure.figsize':(11,8)})
palette = sns.color_palette("bright", 10)

##########################

(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
X_train = X_train.astype(float) / 255.
X_test = X_test.astype(float) / 255.

X_train = X_train.reshape([X_train.shape[0], -1])
X_test = X_test.reshape([X_test.shape[0], -1])

data = X_train[:1000]
label = y_train[:1000]

standardized_data = StandardScaler().fit_transform(data)

pca = decomposition.PCA()
pca.n_components = 50
X = pca.fit_transform(standardized_data)

##########################

MACHINE_EPSILON = np.finfo(np.double).eps
n_components = 2
perplexity = 30


def fit(X):
    n_samples = X.shape[0]
    distances = pairwise_distances(X, metric='euclidean', squared=True)
    P = _joint_probabilities(distances=distances, desired_perplexity=perplexity, verbose=False)
    X_embedded = 1e-4 * np.random.mtrand._rand.randn(n_samples, n_components).astype(np.float32)
    degrees_of_freedom = max(n_components - 1, 1)
    return tsne(P, degrees_of_freedom, n_samples, X_embedded=X_embedded)


def tsne(P, degrees_of_freedom, n_samples, X_embedded):
    params = X_embedded.ravel()
    obj_func = kl_divergence
    params = gradient_descent(obj_func, params, [P, degrees_of_freedom, n_samples, n_components])
    X_embedded = params.reshape(n_samples, n_components)
    return X_embedded


def kl_divergence(params, P, degrees_of_freedom, n_samples, n_components):
    X_embedded = params.reshape(n_samples, n_components)
    dist = pdist(X_embedded, "sqeuclidean")
    dist /= degrees_of_freedom
    dist += 1.
    dist **= (degrees_of_freedom + 1.0) / -2.0
    Q = np.maximum(dist / (2.0 * np.sum(dist)), MACHINE_EPSILON)
    kl_divergence = 2.0 * np.dot(P, np.log(np.maximum(P, MACHINE_EPSILON) / Q))
    grad = np.ndarray((n_samples, n_components), dtype=params.dtype)
    PQd = squareform((P - Q) * dist)
    for i in range(n_samples):
        grad[i] = np.dot(np.ravel(PQd[i], order='K'), X_embedded[i] - X_embedded)
    grad = grad.ravel()
    c = 2.0 * (degrees_of_freedom + 1.0) / degrees_of_freedom
    grad *= c
    return kl_divergence, grad


def gradient_descent(obj_func, p0, args, it=0, n_iter=1000,
                     n_iter_check=1,
                     n_iter_without_progress=300,
                     momentum=0.8,
                     learning_rate=200.0,
                     min_gain=0.01,
                     min_grad_norm=1e-7):
    p = p0.copy().ravel()
    update = np.zeros_like(p)
    gains = np.ones_like(p)
    error = np.finfo(np.float).max
    best_error = np.finfo(np.float).max
    best_iter = i = it
    
    for i in range(it, n_iter):
        error, grad = obj_func(p, *args)
        grad_norm = linalg.norm(grad)
        inc = update * grad < 0.0
        dec = np.invert(inc)
        gains[inc] += 0.2
        gains[dec] *= 0.8
        np.clip(gains, min_gain, np.inf, out=gains)
        grad *= gains
        update = momentum * update - learning_rate * grad
        p += update
        if error < best_error:
                best_error = error
                best_iter = i
        elif i - best_iter > n_iter_without_progress:
            break
        if grad_norm <= min_grad_norm:
            break
    return p

X_embedded = fit(X)
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=label, legend='full', palette=palette)
# Out:
# [t-SNE] Iteration 1: error = 3.3269125, gradient norm = 0.0000067
# [t-SNE] Iteration 2: error = 3.3269125, gradient norm = 0.0000075
# [t-SNE] Iteration 3: error = 3.3269124, gradient norm = 0.0000122
# [t-SNE] Iteration 4: error = 3.3269124, gradient norm = 0.0000245
# [t-SNE] Iteration 5: error = 3.3269120, gradient norm = 0.0000539
# [t-SNE] Iteration 6: error = 3.3269097, gradient norm = 0.0001283
# [t-SNE] Iteration 7: error = 3.3268950, gradient norm = 0.0003280
# [t-SNE] Iteration 8: error = 3.3267854, gradient norm = 0.0008925
# [t-SNE] Iteration 9: error = 3.3258771, gradient norm = 0.0025533
# [t-SNE] Iteration 10: error = 3.3178615, gradient norm = 0.0072396
# [t-SNE] Iteration 11: error = 3.2575215, gradient norm = 0.0164903
# [t-SNE] Iteration 12: error = 3.0105880, gradient norm = 0.0222748
# [t-SNE] Iteration 13: error = 2.6085237, gradient norm = 0.0176570
# [t-SNE] Iteration 14: error = 2.2711886, gradient norm = 0.0127132
# [t-SNE] Iteration 15: error = 2.0290245, gradient norm = 0.0101055
# [t-SNE] Iteration 16: error = 1.8516707, gradient norm = 0.0089005
# [t-SNE] Iteration 17: error = 1.7153165, gradient norm = 0.0079344
# [t-SNE] Iteration 18: error = 1.6082245, gradient norm = 0.0069880
# [t-SNE] Iteration 19: error = 1.5252272, gradient norm = 0.0064233
# [t-SNE] Iteration 20: error = 1.4607338, gradient norm = 0.0062394
# [t-SNE] Iteration 21: error = 1.4084584, gradient norm = 0.0056466
# [t-SNE] Iteration 22: error = 1.3653952, gradient norm = 0.0052223
# [t-SNE] Iteration 23: error = 1.3293373, gradient norm = 0.0049397
# [t-SNE] Iteration 24: error = 1.2990989, gradient norm = 0.0042145
# [t-SNE] Iteration 25: error = 1.2750262, gradient norm = 0.0043668
# [t-SNE] Iteration 26: error = 1.2535300, gradient norm = 0.0041768
# [t-SNE] Iteration 27: error = 1.2341014, gradient norm = 0.0038858
# [t-SNE] Iteration 28: error = 1.2167939, gradient norm = 0.0037035
# [t-SNE] Iteration 29: error = 1.2014894, gradient norm = 0.0033557
# [t-SNE] Iteration 30: error = 1.1881757, gradient norm = 0.0031282
# [t-SNE] Iteration 31: error = 1.1766968, gradient norm = 0.0029652
# [t-SNE] Iteration 32: error = 1.1665997, gradient norm = 0.0027715
# [t-SNE] Iteration 33: error = 1.1575363, gradient norm = 0.0027151
# [t-SNE] Iteration 34: error = 1.1491161, gradient norm = 0.0024423
# [t-SNE] Iteration 35: error = 1.1414147, gradient norm = 0.0023707
# [t-SNE] Iteration 36: error = 1.1341928, gradient norm = 0.0022368
# [t-SNE] Iteration 37: error = 1.1273258, gradient norm = 0.0022225
# [t-SNE] Iteration 38: error = 1.1206520, gradient norm = 0.0020812
# [t-SNE] Iteration 39: error = 1.1142505, gradient norm = 0.0019530
# [t-SNE] Iteration 40: error = 1.1082105, gradient norm = 0.0017838
# [t-SNE] Iteration 41: error = 1.1025779, gradient norm = 0.0017516
# [t-SNE] Iteration 42: error = 1.0971765, gradient norm = 0.0016582
# [t-SNE] Iteration 43: error = 1.0918739, gradient norm = 0.0016164
# [t-SNE] Iteration 44: error = 1.0865327, gradient norm = 0.0015389
# [t-SNE] Iteration 45: error = 1.0811568, gradient norm = 0.0015663
# [t-SNE] Iteration 46: error = 1.0755025, gradient norm = 0.0015888
# [t-SNE] Iteration 47: error = 1.0696818, gradient norm = 0.0014536
# [t-SNE] Iteration 48: error = 1.0657045, gradient norm = 0.0016734
# [t-SNE] Iteration 49: error = 1.0619534, gradient norm = 0.0016656
# [t-SNE] Iteration 50: error = 1.0575627, gradient norm = 0.0016081
# [t-SNE] Iteration 51: error = 1.0528926, gradient norm = 0.0014846
# [t-SNE] Iteration 52: error = 1.0484968, gradient norm = 0.0014366
# [t-SNE] Iteration 53: error = 1.0442721, gradient norm = 0.0014083
# [t-SNE] Iteration 54: error = 1.0400593, gradient norm = 0.0013529
# [t-SNE] Iteration 55: error = 1.0359222, gradient norm = 0.0013127
# [t-SNE] Iteration 56: error = 1.0318920, gradient norm = 0.0012687
# [t-SNE] Iteration 57: error = 1.0279888, gradient norm = 0.0012686
# [t-SNE] Iteration 58: error = 1.0241603, gradient norm = 0.0012425
# [t-SNE] Iteration 59: error = 1.0203808, gradient norm = 0.0012119
# [t-SNE] Iteration 60: error = 1.0166483, gradient norm = 0.0012097
# [t-SNE] Iteration 61: error = 1.0129258, gradient norm = 0.0011846
# [t-SNE] Iteration 62: error = 1.0092349, gradient norm = 0.0011211
# [t-SNE] Iteration 63: error = 1.0056400, gradient norm = 0.0011237
# [t-SNE] Iteration 64: error = 1.0021395, gradient norm = 0.0010999
# [t-SNE] Iteration 65: error = 0.9987751, gradient norm = 0.0010762
# [t-SNE] Iteration 66: error = 0.9954838, gradient norm = 0.0010316
# [t-SNE] Iteration 67: error = 0.9922640, gradient norm = 0.0010017
# [t-SNE] Iteration 68: error = 0.9891283, gradient norm = 0.0010105
# [t-SNE] Iteration 69: error = 0.9860450, gradient norm = 0.0009955
# [t-SNE] Iteration 70: error = 0.9830081, gradient norm = 0.0009708
# [t-SNE] Iteration 71: error = 0.9800344, gradient norm = 0.0009169
# [t-SNE] Iteration 72: error = 0.9771703, gradient norm = 0.0009049
# [t-SNE] Iteration 73: error = 0.9744059, gradient norm = 0.0009135
# [t-SNE] Iteration 74: error = 0.9716795, gradient norm = 0.0008968
# [t-SNE] Iteration 75: error = 0.9689846, gradient norm = 0.0008815
# [t-SNE] Iteration 76: error = 0.9663322, gradient norm = 0.0008383
# [t-SNE] Iteration 77: error = 0.9637581, gradient norm = 0.0008099
# [t-SNE] Iteration 78: error = 0.9612702, gradient norm = 0.0007943
# [t-SNE] Iteration 79: error = 0.9588684, gradient norm = 0.0007965
# [t-SNE] Iteration 80: error = 0.9565441, gradient norm = 0.0007914
# [t-SNE] Iteration 81: error = 0.9542840, gradient norm = 0.0008043
# [t-SNE] Iteration 82: error = 0.9520693, gradient norm = 0.0008296
# [t-SNE] Iteration 83: error = 0.9498942, gradient norm = 0.0008635
# [t-SNE] Iteration 84: error = 0.9477505, gradient norm = 0.0008154
# [t-SNE] Iteration 85: error = 0.9456428, gradient norm = 0.0007280
# [t-SNE] Iteration 86: error = 0.9435730, gradient norm = 0.0007189
# [t-SNE] Iteration 87: error = 0.9415226, gradient norm = 0.0007548
# [t-SNE] Iteration 88: error = 0.9394734, gradient norm = 0.0007084
# [t-SNE] Iteration 89: error = 0.9374232, gradient norm = 0.0006987
# [t-SNE] Iteration 90: error = 0.9353942, gradient norm = 0.0007478
# [t-SNE] Iteration 91: error = 0.9334040, gradient norm = 0.0007541
# [t-SNE] Iteration 92: error = 0.9314659, gradient norm = 0.0007238
# [t-SNE] Iteration 93: error = 0.9295622, gradient norm = 0.0007004
# [t-SNE] Iteration 94: error = 0.9276974, gradient norm = 0.0007332
# [t-SNE] Iteration 95: error = 0.9258567, gradient norm = 0.0007038
# [t-SNE] Iteration 96: error = 0.9240332, gradient norm = 0.0007354
# [t-SNE] Iteration 97: error = 0.9221858, gradient norm = 0.0007705
# [t-SNE] Iteration 98: error = 0.9202915, gradient norm = 0.0008115
# [t-SNE] Iteration 99: error = 0.9183294, gradient norm = 0.0007226
# [t-SNE] Iteration 100: error = 0.9163546, gradient norm = 0.0007404
# [t-SNE] Iteration 101: error = 0.9143389, gradient norm = 0.0007529
# [t-SNE] Iteration 102: error = 0.9122578, gradient norm = 0.0007327
# [t-SNE] Iteration 103: error = 0.9101376, gradient norm = 0.0007771
# [t-SNE] Iteration 104: error = 0.9080291, gradient norm = 0.0007733
# [t-SNE] Iteration 105: error = 0.9060244, gradient norm = 0.0008067
# [t-SNE] Iteration 106: error = 0.9041473, gradient norm = 0.0008347
# [t-SNE] Iteration 107: error = 0.9023571, gradient norm = 0.0008276
# [t-SNE] Iteration 108: error = 0.9006552, gradient norm = 0.0008290
# [t-SNE] Iteration 109: error = 0.8990196, gradient norm = 0.0008081
# [t-SNE] Iteration 110: error = 0.8975196, gradient norm = 0.0008309
# [t-SNE] Iteration 111: error = 0.8960817, gradient norm = 0.0008539
# [t-SNE] Iteration 112: error = 0.8945161, gradient norm = 0.0008498
# [t-SNE] Iteration 113: error = 0.8928899, gradient norm = 0.0007822
# [t-SNE] Iteration 114: error = 0.8914784, gradient norm = 0.0008849
# [t-SNE] Iteration 115: error = 0.8902061, gradient norm = 0.0011401
# [t-SNE] Iteration 116: error = 0.8889484, gradient norm = 0.0013312
# [t-SNE] Iteration 117: error = 0.8876316, gradient norm = 0.0011531
# [t-SNE] Iteration 118: error = 0.8863071, gradient norm = 0.0006387
# [t-SNE] Iteration 119: error = 0.8851317, gradient norm = 0.0010762
# [t-SNE] Iteration 120: error = 0.8838841, gradient norm = 0.0007040
# [t-SNE] Iteration 121: error = 0.8827056, gradient norm = 0.0007999
# [t-SNE] Iteration 122: error = 0.8815115, gradient norm = 0.0008266
# [t-SNE] Iteration 123: error = 0.8802720, gradient norm = 0.0006718
# [t-SNE] Iteration 124: error = 0.8790366, gradient norm = 0.0007796
# [t-SNE] Iteration 125: error = 0.8777801, gradient norm = 0.0005865
# [t-SNE] Iteration 126: error = 0.8766048, gradient norm = 0.0007042
# [t-SNE] Iteration 127: error = 0.8754845, gradient norm = 0.0005443
# [t-SNE] Iteration 128: error = 0.8744593, gradient norm = 0.0006261
# [t-SNE] Iteration 129: error = 0.8734580, gradient norm = 0.0005390
# [t-SNE] Iteration 130: error = 0.8725057, gradient norm = 0.0006286
# [t-SNE] Iteration 131: error = 0.8715867, gradient norm = 0.0005815
# [t-SNE] Iteration 132: error = 0.8707073, gradient norm = 0.0005446
# [t-SNE] Iteration 133: error = 0.8698467, gradient norm = 0.0005554
# [t-SNE] Iteration 134: error = 0.8689680, gradient norm = 0.0005750
# [t-SNE] Iteration 135: error = 0.8680557, gradient norm = 0.0005499
# [t-SNE] Iteration 136: error = 0.8671173, gradient norm = 0.0005500
# [t-SNE] Iteration 137: error = 0.8661564, gradient norm = 0.0005525
# [t-SNE] Iteration 138: error = 0.8651819, gradient norm = 0.0005524
# [t-SNE] Iteration 139: error = 0.8642107, gradient norm = 0.0005913
# [t-SNE] Iteration 140: error = 0.8632419, gradient norm = 0.0005511
# [t-SNE] Iteration 141: error = 0.8622894, gradient norm = 0.0005053
# [t-SNE] Iteration 142: error = 0.8613766, gradient norm = 0.0005214
# [t-SNE] Iteration 143: error = 0.8604792, gradient norm = 0.0005456
# [t-SNE] Iteration 144: error = 0.8595880, gradient norm = 0.0004969
# [t-SNE] Iteration 145: error = 0.8587440, gradient norm = 0.0005053
# [t-SNE] Iteration 146: error = 0.8579127, gradient norm = 0.0004928
# [t-SNE] Iteration 147: error = 0.8571162, gradient norm = 0.0004896
# [t-SNE] Iteration 148: error = 0.8563506, gradient norm = 0.0004879
# [t-SNE] Iteration 149: error = 0.8556113, gradient norm = 0.0004696
# [t-SNE] Iteration 150: error = 0.8548968, gradient norm = 0.0004440
# [t-SNE] Iteration 151: error = 0.8542048, gradient norm = 0.0004323
# [t-SNE] Iteration 152: error = 0.8535245, gradient norm = 0.0004392
# [t-SNE] Iteration 153: error = 0.8528540, gradient norm = 0.0004583
# [t-SNE] Iteration 154: error = 0.8521908, gradient norm = 0.0004427
# [t-SNE] Iteration 155: error = 0.8515359, gradient norm = 0.0004266
# [t-SNE] Iteration 156: error = 0.8508928, gradient norm = 0.0004327
# [t-SNE] Iteration 157: error = 0.8502700, gradient norm = 0.0004629
# [t-SNE] Iteration 158: error = 0.8496760, gradient norm = 0.0004802
# [t-SNE] Iteration 159: error = 0.8490993, gradient norm = 0.0005082
# [t-SNE] Iteration 160: error = 0.8485398, gradient norm = 0.0006416
# [t-SNE] Iteration 161: error = 0.8479414, gradient norm = 0.0004967
# [t-SNE] Iteration 162: error = 0.8473575, gradient norm = 0.0004449
# [t-SNE] Iteration 163: error = 0.8467952, gradient norm = 0.0005175
# [t-SNE] Iteration 164: error = 0.8462161, gradient norm = 0.0003811
# [t-SNE] Iteration 165: error = 0.8456643, gradient norm = 0.0004591
# [t-SNE] Iteration 166: error = 0.8450936, gradient norm = 0.0003767
# [t-SNE] Iteration 167: error = 0.8445290, gradient norm = 0.0004280
# [t-SNE] Iteration 168: error = 0.8439458, gradient norm = 0.0003903
# [t-SNE] Iteration 169: error = 0.8433609, gradient norm = 0.0004139
# [t-SNE] Iteration 170: error = 0.8427808, gradient norm = 0.0004498
# [t-SNE] Iteration 171: error = 0.8422095, gradient norm = 0.0004675
# [t-SNE] Iteration 172: error = 0.8416450, gradient norm = 0.0004078
# [t-SNE] Iteration 173: error = 0.8411080, gradient norm = 0.0002967
# [t-SNE] Iteration 174: error = 0.8406223, gradient norm = 0.0003739
# [t-SNE] Iteration 175: error = 0.8401472, gradient norm = 0.0003004
# [t-SNE] Iteration 176: error = 0.8397044, gradient norm = 0.0003193
# [t-SNE] Iteration 177: error = 0.8392674, gradient norm = 0.0003314
# [t-SNE] Iteration 178: error = 0.8388272, gradient norm = 0.0003096
# [t-SNE] Iteration 179: error = 0.8384037, gradient norm = 0.0003119
# [t-SNE] Iteration 180: error = 0.8380031, gradient norm = 0.0003251
# [t-SNE] Iteration 181: error = 0.8375955, gradient norm = 0.0003171
# [t-SNE] Iteration 182: error = 0.8371958, gradient norm = 0.0003035
# [t-SNE] Iteration 183: error = 0.8368129, gradient norm = 0.0002902
# [t-SNE] Iteration 184: error = 0.8364307, gradient norm = 0.0002940
# [t-SNE] Iteration 185: error = 0.8360427, gradient norm = 0.0002764
# [t-SNE] Iteration 186: error = 0.8356599, gradient norm = 0.0002542
# [t-SNE] Iteration 187: error = 0.8352884, gradient norm = 0.0002560
# [t-SNE] Iteration 188: error = 0.8349204, gradient norm = 0.0002426
# [t-SNE] Iteration 189: error = 0.8345561, gradient norm = 0.0002424
# [t-SNE] Iteration 190: error = 0.8341940, gradient norm = 0.0002529
# [t-SNE] Iteration 191: error = 0.8338266, gradient norm = 0.0002601
# [t-SNE] Iteration 192: error = 0.8334498, gradient norm = 0.0002616
# [t-SNE] Iteration 193: error = 0.8330598, gradient norm = 0.0002543
# [t-SNE] Iteration 194: error = 0.8326534, gradient norm = 0.0002428
# [t-SNE] Iteration 195: error = 0.8322275, gradient norm = 0.0002556
# [t-SNE] Iteration 196: error = 0.8317748, gradient norm = 0.0002752
# [t-SNE] Iteration 197: error = 0.8312918, gradient norm = 0.0002772
# [t-SNE] Iteration 198: error = 0.8307998, gradient norm = 0.0002633
# [t-SNE] Iteration 199: error = 0.8304038, gradient norm = 0.0002936
# [t-SNE] Iteration 200: error = 0.8301186, gradient norm = 0.0003934
# [t-SNE] Iteration 201: error = 0.8298059, gradient norm = 0.0004007
# [t-SNE] Iteration 202: error = 0.8294299, gradient norm = 0.0003396
# [t-SNE] Iteration 203: error = 0.8291385, gradient norm = 0.0003782
# [t-SNE] Iteration 204: error = 0.8288176, gradient norm = 0.0003621
# [t-SNE] Iteration 205: error = 0.8284891, gradient norm = 0.0003116
# [t-SNE] Iteration 206: error = 0.8281612, gradient norm = 0.0002898
# [t-SNE] Iteration 207: error = 0.8278035, gradient norm = 0.0003022
# [t-SNE] Iteration 208: error = 0.8274809, gradient norm = 0.0002924
# [t-SNE] Iteration 209: error = 0.8271961, gradient norm = 0.0002782
# [t-SNE] Iteration 210: error = 0.8269105, gradient norm = 0.0002865
# [t-SNE] Iteration 211: error = 0.8266110, gradient norm = 0.0002827
# [t-SNE] Iteration 212: error = 0.8263095, gradient norm = 0.0002586
# [t-SNE] Iteration 213: error = 0.8260296, gradient norm = 0.0002364
# [t-SNE] Iteration 214: error = 0.8257767, gradient norm = 0.0002444
# [t-SNE] Iteration 215: error = 0.8255366, gradient norm = 0.0002546
# [t-SNE] Iteration 216: error = 0.8252946, gradient norm = 0.0002546
# [t-SNE] Iteration 217: error = 0.8250451, gradient norm = 0.0002441
# [t-SNE] Iteration 218: error = 0.8247882, gradient norm = 0.0002347
# [t-SNE] Iteration 219: error = 0.8245315, gradient norm = 0.0002482
# [t-SNE] Iteration 220: error = 0.8242813, gradient norm = 0.0002654
# [t-SNE] Iteration 221: error = 0.8240282, gradient norm = 0.0002448
# [t-SNE] Iteration 222: error = 0.8237785, gradient norm = 0.0002070
# [t-SNE] Iteration 223: error = 0.8235458, gradient norm = 0.0002051
# [t-SNE] Iteration 224: error = 0.8233205, gradient norm = 0.0002066
# [t-SNE] Iteration 225: error = 0.8230950, gradient norm = 0.0002081
# [t-SNE] Iteration 226: error = 0.8228698, gradient norm = 0.0002029
# [t-SNE] Iteration 227: error = 0.8226455, gradient norm = 0.0001831
# [t-SNE] Iteration 228: error = 0.8224254, gradient norm = 0.0001864
# [t-SNE] Iteration 229: error = 0.8222075, gradient norm = 0.0001920
# [t-SNE] Iteration 230: error = 0.8219907, gradient norm = 0.0001877
# [t-SNE] Iteration 231: error = 0.8217731, gradient norm = 0.0001849
# [t-SNE] Iteration 232: error = 0.8215537, gradient norm = 0.0001860
# [t-SNE] Iteration 233: error = 0.8213334, gradient norm = 0.0001891
# [t-SNE] Iteration 234: error = 0.8211128, gradient norm = 0.0001772
# [t-SNE] Iteration 235: error = 0.8208930, gradient norm = 0.0001769
# [t-SNE] Iteration 236: error = 0.8206742, gradient norm = 0.0001847
# [t-SNE] Iteration 237: error = 0.8204547, gradient norm = 0.0001840
# [t-SNE] Iteration 238: error = 0.8202336, gradient norm = 0.0001729
# [t-SNE] Iteration 239: error = 0.8200115, gradient norm = 0.0001759
# [t-SNE] Iteration 240: error = 0.8197876, gradient norm = 0.0001800
# [t-SNE] Iteration 241: error = 0.8195627, gradient norm = 0.0001832
# [t-SNE] Iteration 242: error = 0.8193382, gradient norm = 0.0001703
# [t-SNE] Iteration 243: error = 0.8191151, gradient norm = 0.0001645
# [t-SNE] Iteration 244: error = 0.8188930, gradient norm = 0.0001764
# [t-SNE] Iteration 245: error = 0.8186698, gradient norm = 0.0001786
# [t-SNE] Iteration 246: error = 0.8184456, gradient norm = 0.0001728
# [t-SNE] Iteration 247: error = 0.8182207, gradient norm = 0.0001694
# [t-SNE] Iteration 248: error = 0.8179945, gradient norm = 0.0001684
# [t-SNE] Iteration 249: error = 0.8177680, gradient norm = 0.0001660
# [t-SNE] Iteration 250: error = 0.8175408, gradient norm = 0.0001645
# [t-SNE] Iteration 251: error = 0.8173126, gradient norm = 0.0001640
# [t-SNE] Iteration 252: error = 0.8170833, gradient norm = 0.0001706
# [t-SNE] Iteration 253: error = 0.8168518, gradient norm = 0.0001722
# [t-SNE] Iteration 254: error = 0.8166182, gradient norm = 0.0001788
# [t-SNE] Iteration 255: error = 0.8163814, gradient norm = 0.0001830
# [t-SNE] Iteration 256: error = 0.8161399, gradient norm = 0.0001801
# [t-SNE] Iteration 257: error = 0.8158948, gradient norm = 0.0001818
# [t-SNE] Iteration 258: error = 0.8156461, gradient norm = 0.0001837
# [t-SNE] Iteration 259: error = 0.8153945, gradient norm = 0.0001710
# [t-SNE] Iteration 260: error = 0.8151439, gradient norm = 0.0001822
# [t-SNE] Iteration 261: error = 0.8148930, gradient norm = 0.0001813
# [t-SNE] Iteration 262: error = 0.8146415, gradient norm = 0.0001810
# [t-SNE] Iteration 263: error = 0.8143896, gradient norm = 0.0001884
# [t-SNE] Iteration 264: error = 0.8141352, gradient norm = 0.0001763
# [t-SNE] Iteration 265: error = 0.8138803, gradient norm = 0.0001719
# [t-SNE] Iteration 266: error = 0.8136249, gradient norm = 0.0001775
# [t-SNE] Iteration 267: error = 0.8133665, gradient norm = 0.0001967
# [t-SNE] Iteration 268: error = 0.8131013, gradient norm = 0.0001930
# [t-SNE] Iteration 269: error = 0.8128309, gradient norm = 0.0001931
# [t-SNE] Iteration 270: error = 0.8125593, gradient norm = 0.0002273
# [t-SNE] Iteration 271: error = 0.8122889, gradient norm = 0.0002868
# [t-SNE] Iteration 272: error = 0.8120182, gradient norm = 0.0003350
# [t-SNE] Iteration 273: error = 0.8117405, gradient norm = 0.0002328
# [t-SNE] Iteration 274: error = 0.8114689, gradient norm = 0.0002537
# [t-SNE] Iteration 275: error = 0.8111982, gradient norm = 0.0002547
# [t-SNE] Iteration 276: error = 0.8109292, gradient norm = 0.0002312
# [t-SNE] Iteration 277: error = 0.8106641, gradient norm = 0.0002417
# [t-SNE] Iteration 278: error = 0.8104013, gradient norm = 0.0002093
# [t-SNE] Iteration 279: error = 0.8101451, gradient norm = 0.0002278
# [t-SNE] Iteration 280: error = 0.8098943, gradient norm = 0.0002120
# [t-SNE] Iteration 281: error = 0.8096524, gradient norm = 0.0002029
# [t-SNE] Iteration 282: error = 0.8094189, gradient norm = 0.0001873
# [t-SNE] Iteration 283: error = 0.8091945, gradient norm = 0.0002049
# [t-SNE] Iteration 284: error = 0.8089749, gradient norm = 0.0002176
# [t-SNE] Iteration 285: error = 0.8087522, gradient norm = 0.0002095
# [t-SNE] Iteration 286: error = 0.8085218, gradient norm = 0.0002024
# [t-SNE] Iteration 287: error = 0.8082836, gradient norm = 0.0001893
# [t-SNE] Iteration 288: error = 0.8080414, gradient norm = 0.0002074
# [t-SNE] Iteration 289: error = 0.8077962, gradient norm = 0.0001857
# [t-SNE] Iteration 290: error = 0.8075611, gradient norm = 0.0001945
# [t-SNE] Iteration 291: error = 0.8073435, gradient norm = 0.0002077
# [t-SNE] Iteration 292: error = 0.8071349, gradient norm = 0.0002254
# [t-SNE] Iteration 293: error = 0.8069210, gradient norm = 0.0002197
# [t-SNE] Iteration 294: error = 0.8066979, gradient norm = 0.0002211
# [t-SNE] Iteration 295: error = 0.8064714, gradient norm = 0.0002088
# [t-SNE] Iteration 296: error = 0.8062514, gradient norm = 0.0001967
# [t-SNE] Iteration 297: error = 0.8060398, gradient norm = 0.0001847
# [t-SNE] Iteration 298: error = 0.8058342, gradient norm = 0.0001831
# [t-SNE] Iteration 299: error = 0.8056380, gradient norm = 0.0001806
# [t-SNE] Iteration 300: error = 0.8054564, gradient norm = 0.0001839
# [t-SNE] Iteration 301: error = 0.8052891, gradient norm = 0.0001642
# [t-SNE] Iteration 302: error = 0.8051374, gradient norm = 0.0001608
# [t-SNE] Iteration 303: error = 0.8049997, gradient norm = 0.0001635
# [t-SNE] Iteration 304: error = 0.8048723, gradient norm = 0.0001783
# [t-SNE] Iteration 305: error = 0.8047491, gradient norm = 0.0001747
# [t-SNE] Iteration 306: error = 0.8046249, gradient norm = 0.0001634
# [t-SNE] Iteration 307: error = 0.8045001, gradient norm = 0.0001656
# [t-SNE] Iteration 308: error = 0.8043739, gradient norm = 0.0001610
# [t-SNE] Iteration 309: error = 0.8042486, gradient norm = 0.0001502
# [t-SNE] Iteration 310: error = 0.8041266, gradient norm = 0.0001480
# [t-SNE] Iteration 311: error = 0.8040084, gradient norm = 0.0001461
# [t-SNE] Iteration 312: error = 0.8038930, gradient norm = 0.0001462
# [t-SNE] Iteration 313: error = 0.8037796, gradient norm = 0.0001313
# [t-SNE] Iteration 314: error = 0.8036683, gradient norm = 0.0001391
# [t-SNE] Iteration 315: error = 0.8035584, gradient norm = 0.0001454
# [t-SNE] Iteration 316: error = 0.8034497, gradient norm = 0.0001446
# [t-SNE] Iteration 317: error = 0.8033417, gradient norm = 0.0001309
# [t-SNE] Iteration 318: error = 0.8032351, gradient norm = 0.0001324
# [t-SNE] Iteration 319: error = 0.8031290, gradient norm = 0.0001373
# [t-SNE] Iteration 320: error = 0.8030232, gradient norm = 0.0001368
# [t-SNE] Iteration 321: error = 0.8029181, gradient norm = 0.0001232
# [t-SNE] Iteration 322: error = 0.8028137, gradient norm = 0.0001234
# [t-SNE] Iteration 323: error = 0.8027096, gradient norm = 0.0001262
# [t-SNE] Iteration 324: error = 0.8026058, gradient norm = 0.0001227
# [t-SNE] Iteration 325: error = 0.8025016, gradient norm = 0.0001184
# [t-SNE] Iteration 326: error = 0.8023965, gradient norm = 0.0001252
# [t-SNE] Iteration 327: error = 0.8022890, gradient norm = 0.0001318
# [t-SNE] Iteration 328: error = 0.8021772, gradient norm = 0.0001382
# [t-SNE] Iteration 329: error = 0.8020597, gradient norm = 0.0001541
# [t-SNE] Iteration 330: error = 0.8019375, gradient norm = 0.0001496
# [t-SNE] Iteration 331: error = 0.8018294, gradient norm = 0.0001860
# [t-SNE] Iteration 332: error = 0.8017162, gradient norm = 0.0001896
# [t-SNE] Iteration 333: error = 0.8015975, gradient norm = 0.0001492
# [t-SNE] Iteration 334: error = 0.8014887, gradient norm = 0.0001453
# [t-SNE] Iteration 335: error = 0.8013775, gradient norm = 0.0001426
# [t-SNE] Iteration 336: error = 0.8012687, gradient norm = 0.0001344
# [t-SNE] Iteration 337: error = 0.8011655, gradient norm = 0.0001482
# [t-SNE] Iteration 338: error = 0.8010568, gradient norm = 0.0001351
# [t-SNE] Iteration 339: error = 0.8009512, gradient norm = 0.0001241
# [t-SNE] Iteration 340: error = 0.8008486, gradient norm = 0.0001290
# [t-SNE] Iteration 341: error = 0.8007438, gradient norm = 0.0001191
# [t-SNE] Iteration 342: error = 0.8006407, gradient norm = 0.0001188
# [t-SNE] Iteration 343: error = 0.8005400, gradient norm = 0.0001279
# [t-SNE] Iteration 344: error = 0.8004394, gradient norm = 0.0001350
# [t-SNE] Iteration 345: error = 0.8003374, gradient norm = 0.0001248
# [t-SNE] Iteration 346: error = 0.8002353, gradient norm = 0.0001176
# [t-SNE] Iteration 347: error = 0.8001343, gradient norm = 0.0001164
# [t-SNE] Iteration 348: error = 0.8000340, gradient norm = 0.0001242
# [t-SNE] Iteration 349: error = 0.7999334, gradient norm = 0.0001318
# [t-SNE] Iteration 350: error = 0.7998317, gradient norm = 0.0001354
# [t-SNE] Iteration 351: error = 0.7997289, gradient norm = 0.0001378
# [t-SNE] Iteration 352: error = 0.7996259, gradient norm = 0.0001271
# [t-SNE] Iteration 353: error = 0.7995226, gradient norm = 0.0001164
# [t-SNE] Iteration 354: error = 0.7994199, gradient norm = 0.0001179
# [t-SNE] Iteration 355: error = 0.7993177, gradient norm = 0.0001179
# [t-SNE] Iteration 356: error = 0.7992159, gradient norm = 0.0001215
# [t-SNE] Iteration 357: error = 0.7991146, gradient norm = 0.0001086
# [t-SNE] Iteration 358: error = 0.7990143, gradient norm = 0.0001104
# [t-SNE] Iteration 359: error = 0.7989150, gradient norm = 0.0001139
# [t-SNE] Iteration 360: error = 0.7988162, gradient norm = 0.0001079
# [t-SNE] Iteration 361: error = 0.7987184, gradient norm = 0.0001073
# [t-SNE] Iteration 362: error = 0.7986210, gradient norm = 0.0001067
# [t-SNE] Iteration 363: error = 0.7985246, gradient norm = 0.0001093
# [t-SNE] Iteration 364: error = 0.7984283, gradient norm = 0.0001115
# [t-SNE] Iteration 365: error = 0.7983325, gradient norm = 0.0001082
# [t-SNE] Iteration 366: error = 0.7982374, gradient norm = 0.0001013
# [t-SNE] Iteration 367: error = 0.7981436, gradient norm = 0.0001067
# [t-SNE] Iteration 368: error = 0.7980512, gradient norm = 0.0001163
# [t-SNE] Iteration 369: error = 0.7979596, gradient norm = 0.0001071
# [t-SNE] Iteration 370: error = 0.7978692, gradient norm = 0.0001019
# [t-SNE] Iteration 371: error = 0.7977804, gradient norm = 0.0000993
# [t-SNE] Iteration 372: error = 0.7976937, gradient norm = 0.0001035
# [t-SNE] Iteration 373: error = 0.7976073, gradient norm = 0.0000985
# [t-SNE] Iteration 374: error = 0.7975221, gradient norm = 0.0000978
# [t-SNE] Iteration 375: error = 0.7974383, gradient norm = 0.0001011
# [t-SNE] Iteration 376: error = 0.7973546, gradient norm = 0.0000971
# [t-SNE] Iteration 377: error = 0.7972723, gradient norm = 0.0000978
# [t-SNE] Iteration 378: error = 0.7971906, gradient norm = 0.0001026
# [t-SNE] Iteration 379: error = 0.7971100, gradient norm = 0.0001105
# [t-SNE] Iteration 380: error = 0.7970294, gradient norm = 0.0001118
# [t-SNE] Iteration 381: error = 0.7969497, gradient norm = 0.0001094
# [t-SNE] Iteration 382: error = 0.7968712, gradient norm = 0.0001082
# [t-SNE] Iteration 383: error = 0.7967933, gradient norm = 0.0001026
# [t-SNE] Iteration 384: error = 0.7967165, gradient norm = 0.0001062
# [t-SNE] Iteration 385: error = 0.7966408, gradient norm = 0.0001153
# [t-SNE] Iteration 386: error = 0.7965652, gradient norm = 0.0001031
# [t-SNE] Iteration 387: error = 0.7964905, gradient norm = 0.0000944
# [t-SNE] Iteration 388: error = 0.7964171, gradient norm = 0.0001061
# [t-SNE] Iteration 389: error = 0.7963441, gradient norm = 0.0001003
# [t-SNE] Iteration 390: error = 0.7962711, gradient norm = 0.0000860
# [t-SNE] Iteration 391: error = 0.7961994, gradient norm = 0.0000986
# [t-SNE] Iteration 392: error = 0.7961278, gradient norm = 0.0000943
# [t-SNE] Iteration 393: error = 0.7960563, gradient norm = 0.0000837
# [t-SNE] Iteration 394: error = 0.7959855, gradient norm = 0.0000962
# [t-SNE] Iteration 395: error = 0.7959145, gradient norm = 0.0000920
# [t-SNE] Iteration 396: error = 0.7958436, gradient norm = 0.0000876
# [t-SNE] Iteration 397: error = 0.7957728, gradient norm = 0.0000904
# [t-SNE] Iteration 398: error = 0.7957020, gradient norm = 0.0000891
# [t-SNE] Iteration 399: error = 0.7956313, gradient norm = 0.0000860
# [t-SNE] Iteration 400: error = 0.7955607, gradient norm = 0.0000870
# [t-SNE] Iteration 401: error = 0.7954902, gradient norm = 0.0000874
# [t-SNE] Iteration 402: error = 0.7954198, gradient norm = 0.0000837
# [t-SNE] Iteration 403: error = 0.7953497, gradient norm = 0.0000885
# [t-SNE] Iteration 404: error = 0.7952797, gradient norm = 0.0000896
# [t-SNE] Iteration 405: error = 0.7952097, gradient norm = 0.0000867
# [t-SNE] Iteration 406: error = 0.7951398, gradient norm = 0.0000905
# [t-SNE] Iteration 407: error = 0.7950700, gradient norm = 0.0000912
# [t-SNE] Iteration 408: error = 0.7950003, gradient norm = 0.0000902
# [t-SNE] Iteration 409: error = 0.7949306, gradient norm = 0.0000894
# [t-SNE] Iteration 410: error = 0.7948607, gradient norm = 0.0000894
# [t-SNE] Iteration 411: error = 0.7947899, gradient norm = 0.0000906
# [t-SNE] Iteration 412: error = 0.7947162, gradient norm = 0.0000998
# [t-SNE] Iteration 413: error = 0.7946351, gradient norm = 0.0001156
# [t-SNE] Iteration 414: error = 0.7945348, gradient norm = 0.0001504
# [t-SNE] Iteration 415: error = 0.7944033, gradient norm = 0.0001957
# [t-SNE] Iteration 416: error = 0.7942509, gradient norm = 0.0001750
# [t-SNE] Iteration 417: error = 0.7941498, gradient norm = 0.0001388
# [t-SNE] Iteration 418: error = 0.7941055, gradient norm = 0.0001864
# [t-SNE] Iteration 419: error = 0.7940301, gradient norm = 0.0001696
# [t-SNE] Iteration 420: error = 0.7939499, gradient norm = 0.0001632
# [t-SNE] Iteration 421: error = 0.7938791, gradient norm = 0.0001625
# [t-SNE] Iteration 422: error = 0.7938104, gradient norm = 0.0001606
# [t-SNE] Iteration 423: error = 0.7937377, gradient norm = 0.0001541
# [t-SNE] Iteration 424: error = 0.7936620, gradient norm = 0.0001402
# [t-SNE] Iteration 425: error = 0.7935870, gradient norm = 0.0001268
# [t-SNE] Iteration 426: error = 0.7935158, gradient norm = 0.0001151
# [t-SNE] Iteration 427: error = 0.7934484, gradient norm = 0.0001145
# [t-SNE] Iteration 428: error = 0.7933828, gradient norm = 0.0001157
# [t-SNE] Iteration 429: error = 0.7933177, gradient norm = 0.0001105
# [t-SNE] Iteration 430: error = 0.7932530, gradient norm = 0.0001029
# [t-SNE] Iteration 431: error = 0.7931890, gradient norm = 0.0001010
# [t-SNE] Iteration 432: error = 0.7931247, gradient norm = 0.0001059
# [t-SNE] Iteration 433: error = 0.7930589, gradient norm = 0.0001108
# [t-SNE] Iteration 434: error = 0.7929925, gradient norm = 0.0001065
# [t-SNE] Iteration 435: error = 0.7929307, gradient norm = 0.0001104
# [t-SNE] Iteration 436: error = 0.7928722, gradient norm = 0.0001232
# [t-SNE] Iteration 437: error = 0.7928117, gradient norm = 0.0001204
# [t-SNE] Iteration 438: error = 0.7927513, gradient norm = 0.0001078
# [t-SNE] Iteration 439: error = 0.7926931, gradient norm = 0.0001009
# [t-SNE] Iteration 440: error = 0.7926362, gradient norm = 0.0000928
# [t-SNE] Iteration 441: error = 0.7925795, gradient norm = 0.0000954
# [t-SNE] Iteration 442: error = 0.7925225, gradient norm = 0.0000988
# [t-SNE] Iteration 443: error = 0.7924654, gradient norm = 0.0000966
# [t-SNE] Iteration 444: error = 0.7924094, gradient norm = 0.0000887
# [t-SNE] Iteration 445: error = 0.7923546, gradient norm = 0.0000861
# [t-SNE] Iteration 446: error = 0.7923003, gradient norm = 0.0000899
# [t-SNE] Iteration 447: error = 0.7922459, gradient norm = 0.0000977
# [t-SNE] Iteration 448: error = 0.7921917, gradient norm = 0.0001037
# [t-SNE] Iteration 449: error = 0.7921374, gradient norm = 0.0000935
# [t-SNE] Iteration 450: error = 0.7920838, gradient norm = 0.0000775
# [t-SNE] Iteration 451: error = 0.7920312, gradient norm = 0.0000842
# [t-SNE] Iteration 452: error = 0.7919791, gradient norm = 0.0000948
# [t-SNE] Iteration 453: error = 0.7919269, gradient norm = 0.0001018
# [t-SNE] Iteration 454: error = 0.7918746, gradient norm = 0.0000798
# [t-SNE] Iteration 455: error = 0.7918230, gradient norm = 0.0000737
# [t-SNE] Iteration 456: error = 0.7917719, gradient norm = 0.0000837
# [t-SNE] Iteration 457: error = 0.7917211, gradient norm = 0.0000982
# [t-SNE] Iteration 458: error = 0.7916701, gradient norm = 0.0000881
# [t-SNE] Iteration 459: error = 0.7916192, gradient norm = 0.0000760
# [t-SNE] Iteration 460: error = 0.7915691, gradient norm = 0.0000919
# [t-SNE] Iteration 461: error = 0.7915194, gradient norm = 0.0001110
# [t-SNE] Iteration 462: error = 0.7914697, gradient norm = 0.0001155
# [t-SNE] Iteration 463: error = 0.7914199, gradient norm = 0.0000857
# [t-SNE] Iteration 464: error = 0.7913711, gradient norm = 0.0000986
# [t-SNE] Iteration 465: error = 0.7913221, gradient norm = 0.0000987
# [t-SNE] Iteration 466: error = 0.7912733, gradient norm = 0.0000801
# [t-SNE] Iteration 467: error = 0.7912252, gradient norm = 0.0000908
# [t-SNE] Iteration 468: error = 0.7911774, gradient norm = 0.0000950
# [t-SNE] Iteration 469: error = 0.7911296, gradient norm = 0.0000938
# [t-SNE] Iteration 470: error = 0.7910817, gradient norm = 0.0000739
# [t-SNE] Iteration 471: error = 0.7910348, gradient norm = 0.0000829
# [t-SNE] Iteration 472: error = 0.7909880, gradient norm = 0.0000880
# [t-SNE] Iteration 473: error = 0.7909413, gradient norm = 0.0000851
# [t-SNE] Iteration 474: error = 0.7908950, gradient norm = 0.0000773
# [t-SNE] Iteration 475: error = 0.7908490, gradient norm = 0.0000754
# [t-SNE] Iteration 476: error = 0.7908033, gradient norm = 0.0000858
# [t-SNE] Iteration 477: error = 0.7907577, gradient norm = 0.0000857
# [t-SNE] Iteration 478: error = 0.7907123, gradient norm = 0.0000728
# [t-SNE] Iteration 479: error = 0.7906674, gradient norm = 0.0000731
# [t-SNE] Iteration 480: error = 0.7906228, gradient norm = 0.0000812
# [t-SNE] Iteration 481: error = 0.7905784, gradient norm = 0.0000916
# [t-SNE] Iteration 482: error = 0.7905340, gradient norm = 0.0000746
# [t-SNE] Iteration 483: error = 0.7904900, gradient norm = 0.0000686
# [t-SNE] Iteration 484: error = 0.7904465, gradient norm = 0.0000770
# [t-SNE] Iteration 485: error = 0.7904032, gradient norm = 0.0000859
# [t-SNE] Iteration 486: error = 0.7903598, gradient norm = 0.0000758
# [t-SNE] Iteration 487: error = 0.7903168, gradient norm = 0.0000673
# [t-SNE] Iteration 488: error = 0.7902740, gradient norm = 0.0000713
# [t-SNE] Iteration 489: error = 0.7902314, gradient norm = 0.0000847
# [t-SNE] Iteration 490: error = 0.7901887, gradient norm = 0.0000973
# [t-SNE] Iteration 491: error = 0.7901457, gradient norm = 0.0000843
# [t-SNE] Iteration 492: error = 0.7901029, gradient norm = 0.0000668
# [t-SNE] Iteration 493: error = 0.7900607, gradient norm = 0.0000752
# [t-SNE] Iteration 494: error = 0.7900187, gradient norm = 0.0000841
# [t-SNE] Iteration 495: error = 0.7899767, gradient norm = 0.0000707
# [t-SNE] Iteration 496: error = 0.7899350, gradient norm = 0.0000669
# [t-SNE] Iteration 497: error = 0.7898938, gradient norm = 0.0000777
# [t-SNE] Iteration 498: error = 0.7898525, gradient norm = 0.0000720
# [t-SNE] Iteration 499: error = 0.7898115, gradient norm = 0.0000661
# [t-SNE] Iteration 500: error = 0.7897709, gradient norm = 0.0000771
# [t-SNE] Iteration 501: error = 0.7897303, gradient norm = 0.0000741
# [t-SNE] Iteration 502: error = 0.7896898, gradient norm = 0.0000713
# [t-SNE] Iteration 503: error = 0.7896495, gradient norm = 0.0000707
# [t-SNE] Iteration 504: error = 0.7896095, gradient norm = 0.0000767
# [t-SNE] Iteration 505: error = 0.7895696, gradient norm = 0.0000691
# [t-SNE] Iteration 506: error = 0.7895300, gradient norm = 0.0000699
# [t-SNE] Iteration 507: error = 0.7894905, gradient norm = 0.0000740
# [t-SNE] Iteration 508: error = 0.7894510, gradient norm = 0.0000710
# [t-SNE] Iteration 509: error = 0.7894114, gradient norm = 0.0000670
# [t-SNE] Iteration 510: error = 0.7893713, gradient norm = 0.0000690
# [t-SNE] Iteration 511: error = 0.7893297, gradient norm = 0.0000751
# [t-SNE] Iteration 512: error = 0.7892862, gradient norm = 0.0000907
# [t-SNE] Iteration 513: error = 0.7892421, gradient norm = 0.0000996
# [t-SNE] Iteration 514: error = 0.7891966, gradient norm = 0.0000905
# [t-SNE] Iteration 515: error = 0.7891508, gradient norm = 0.0000801
# [t-SNE] Iteration 516: error = 0.7891075, gradient norm = 0.0000808
# [t-SNE] Iteration 517: error = 0.7890662, gradient norm = 0.0000907
# [t-SNE] Iteration 518: error = 0.7890258, gradient norm = 0.0000868
# [t-SNE] Iteration 519: error = 0.7889855, gradient norm = 0.0000873
# [t-SNE] Iteration 520: error = 0.7889447, gradient norm = 0.0000915
# [t-SNE] Iteration 521: error = 0.7889035, gradient norm = 0.0000917
# [t-SNE] Iteration 522: error = 0.7888620, gradient norm = 0.0000795
# [t-SNE] Iteration 523: error = 0.7888212, gradient norm = 0.0000737
# [t-SNE] Iteration 524: error = 0.7887813, gradient norm = 0.0000754
# [t-SNE] Iteration 525: error = 0.7887421, gradient norm = 0.0000710
# [t-SNE] Iteration 526: error = 0.7887033, gradient norm = 0.0000658
# [t-SNE] Iteration 527: error = 0.7886646, gradient norm = 0.0000716
# [t-SNE] Iteration 528: error = 0.7886255, gradient norm = 0.0000716
# [t-SNE] Iteration 529: error = 0.7885847, gradient norm = 0.0000702
# [t-SNE] Iteration 530: error = 0.7885399, gradient norm = 0.0000853
# [t-SNE] Iteration 531: error = 0.7884846, gradient norm = 0.0000964
# [t-SNE] Iteration 532: error = 0.7884168, gradient norm = 0.0000955
# [t-SNE] Iteration 533: error = 0.7883667, gradient norm = 0.0001086
# [t-SNE] Iteration 534: error = 0.7883510, gradient norm = 0.0001505
# [t-SNE] Iteration 535: error = 0.7883059, gradient norm = 0.0001342
# [t-SNE] Iteration 536: error = 0.7882530, gradient norm = 0.0000892
# [t-SNE] Iteration 537: error = 0.7882264, gradient norm = 0.0001436
# [t-SNE] Iteration 538: error = 0.7881877, gradient norm = 0.0001124
# [t-SNE] Iteration 539: error = 0.7881495, gradient norm = 0.0000924
# [t-SNE] Iteration 540: error = 0.7881164, gradient norm = 0.0001060
# [t-SNE] Iteration 541: error = 0.7880784, gradient norm = 0.0000997
# [t-SNE] Iteration 542: error = 0.7880386, gradient norm = 0.0000849
# [t-SNE] Iteration 543: error = 0.7880014, gradient norm = 0.0000743
# [t-SNE] Iteration 544: error = 0.7879673, gradient norm = 0.0000737
# [t-SNE] Iteration 545: error = 0.7879344, gradient norm = 0.0000798
# [t-SNE] Iteration 546: error = 0.7879006, gradient norm = 0.0000804
# [t-SNE] Iteration 547: error = 0.7878659, gradient norm = 0.0000801
# [t-SNE] Iteration 548: error = 0.7878303, gradient norm = 0.0000787
# [t-SNE] Iteration 549: error = 0.7877944, gradient norm = 0.0000742
# [t-SNE] Iteration 550: error = 0.7877590, gradient norm = 0.0000659
# [t-SNE] Iteration 551: error = 0.7877246, gradient norm = 0.0000645
# [t-SNE] Iteration 552: error = 0.7876910, gradient norm = 0.0000661
# [t-SNE] Iteration 553: error = 0.7876577, gradient norm = 0.0000701
# [t-SNE] Iteration 554: error = 0.7876246, gradient norm = 0.0000706
# [t-SNE] Iteration 555: error = 0.7875914, gradient norm = 0.0000736
# [t-SNE] Iteration 556: error = 0.7875581, gradient norm = 0.0000702
# [t-SNE] Iteration 557: error = 0.7875251, gradient norm = 0.0000652
# [t-SNE] Iteration 558: error = 0.7874924, gradient norm = 0.0000606
# [t-SNE] Iteration 559: error = 0.7874599, gradient norm = 0.0000610
# [t-SNE] Iteration 560: error = 0.7874278, gradient norm = 0.0000634
# [t-SNE] Iteration 561: error = 0.7873958, gradient norm = 0.0000580
# [t-SNE] Iteration 562: error = 0.7873640, gradient norm = 0.0000585
# [t-SNE] Iteration 563: error = 0.7873323, gradient norm = 0.0000613
# [t-SNE] Iteration 564: error = 0.7873007, gradient norm = 0.0000575
# [t-SNE] Iteration 565: error = 0.7872693, gradient norm = 0.0000573
# [t-SNE] Iteration 566: error = 0.7872379, gradient norm = 0.0000608
# [t-SNE] Iteration 567: error = 0.7872063, gradient norm = 0.0000579
# [t-SNE] Iteration 568: error = 0.7871749, gradient norm = 0.0000550
# [t-SNE] Iteration 569: error = 0.7871436, gradient norm = 0.0000572
# [t-SNE] Iteration 570: error = 0.7871124, gradient norm = 0.0000560
# [t-SNE] Iteration 571: error = 0.7870811, gradient norm = 0.0000559
# [t-SNE] Iteration 572: error = 0.7870500, gradient norm = 0.0000586
# [t-SNE] Iteration 573: error = 0.7870188, gradient norm = 0.0000602
# [t-SNE] Iteration 574: error = 0.7869878, gradient norm = 0.0000617
# [t-SNE] Iteration 575: error = 0.7869566, gradient norm = 0.0000587
# [t-SNE] Iteration 576: error = 0.7869256, gradient norm = 0.0000598
# [t-SNE] Iteration 577: error = 0.7868947, gradient norm = 0.0000628
# [t-SNE] Iteration 578: error = 0.7868636, gradient norm = 0.0000622
# [t-SNE] Iteration 579: error = 0.7868326, gradient norm = 0.0000600
# [t-SNE] Iteration 580: error = 0.7868016, gradient norm = 0.0000543
# [t-SNE] Iteration 581: error = 0.7867707, gradient norm = 0.0000568
# [t-SNE] Iteration 582: error = 0.7867399, gradient norm = 0.0000594
# [t-SNE] Iteration 583: error = 0.7867089, gradient norm = 0.0000559
# [t-SNE] Iteration 584: error = 0.7866781, gradient norm = 0.0000565
# [t-SNE] Iteration 585: error = 0.7866472, gradient norm = 0.0000545
# [t-SNE] Iteration 586: error = 0.7866164, gradient norm = 0.0000532
# [t-SNE] Iteration 587: error = 0.7865858, gradient norm = 0.0000540
# [t-SNE] Iteration 588: error = 0.7865551, gradient norm = 0.0000568
# [t-SNE] Iteration 589: error = 0.7865244, gradient norm = 0.0000555
# [t-SNE] Iteration 590: error = 0.7864937, gradient norm = 0.0000533
# [t-SNE] Iteration 591: error = 0.7864630, gradient norm = 0.0000539
# [t-SNE] Iteration 592: error = 0.7864323, gradient norm = 0.0000551
# [t-SNE] Iteration 593: error = 0.7864016, gradient norm = 0.0000580
# [t-SNE] Iteration 594: error = 0.7863709, gradient norm = 0.0000548
# [t-SNE] Iteration 595: error = 0.7863403, gradient norm = 0.0000554
# [t-SNE] Iteration 596: error = 0.7863098, gradient norm = 0.0000588
# [t-SNE] Iteration 597: error = 0.7862793, gradient norm = 0.0000628
# [t-SNE] Iteration 598: error = 0.7862488, gradient norm = 0.0000600
# [t-SNE] Iteration 599: error = 0.7862183, gradient norm = 0.0000571
# [t-SNE] Iteration 600: error = 0.7861882, gradient norm = 0.0000559
# [t-SNE] Iteration 601: error = 0.7861583, gradient norm = 0.0000559
# [t-SNE] Iteration 602: error = 0.7861284, gradient norm = 0.0000534
# [t-SNE] Iteration 603: error = 0.7860988, gradient norm = 0.0000536
# [t-SNE] Iteration 604: error = 0.7860693, gradient norm = 0.0000570
# [t-SNE] Iteration 605: error = 0.7860397, gradient norm = 0.0000529
# [t-SNE] Iteration 606: error = 0.7860103, gradient norm = 0.0000553
# [t-SNE] Iteration 607: error = 0.7859809, gradient norm = 0.0000532
# [t-SNE] Iteration 608: error = 0.7859515, gradient norm = 0.0000529
# [t-SNE] Iteration 609: error = 0.7859220, gradient norm = 0.0000508
# [t-SNE] Iteration 610: error = 0.7858925, gradient norm = 0.0000509
# [t-SNE] Iteration 611: error = 0.7858629, gradient norm = 0.0000518
# [t-SNE] Iteration 612: error = 0.7858332, gradient norm = 0.0000550
# [t-SNE] Iteration 613: error = 0.7858034, gradient norm = 0.0000576
# [t-SNE] Iteration 614: error = 0.7857736, gradient norm = 0.0000725
# [t-SNE] Iteration 615: error = 0.7857438, gradient norm = 0.0000904
# [t-SNE] Iteration 616: error = 0.7857137, gradient norm = 0.0000934
# [t-SNE] Iteration 617: error = 0.7856832, gradient norm = 0.0000683
# [t-SNE] Iteration 618: error = 0.7856527, gradient norm = 0.0000519
# [t-SNE] Iteration 619: error = 0.7856228, gradient norm = 0.0000734
# [t-SNE] Iteration 620: error = 0.7855922, gradient norm = 0.0000585
# [t-SNE] Iteration 621: error = 0.7855616, gradient norm = 0.0000557
# [t-SNE] Iteration 622: error = 0.7855312, gradient norm = 0.0000668
# [t-SNE] Iteration 623: error = 0.7855005, gradient norm = 0.0000543
# [t-SNE] Iteration 624: error = 0.7854698, gradient norm = 0.0000645
# [t-SNE] Iteration 625: error = 0.7854389, gradient norm = 0.0000575
# [t-SNE] Iteration 626: error = 0.7854080, gradient norm = 0.0000600
# [t-SNE] Iteration 627: error = 0.7853770, gradient norm = 0.0000588
# [t-SNE] Iteration 628: error = 0.7853463, gradient norm = 0.0000606
# [t-SNE] Iteration 629: error = 0.7853154, gradient norm = 0.0000596
# [t-SNE] Iteration 630: error = 0.7852844, gradient norm = 0.0000539
# [t-SNE] Iteration 631: error = 0.7852535, gradient norm = 0.0000539
# [t-SNE] Iteration 632: error = 0.7852226, gradient norm = 0.0000567
# [t-SNE] Iteration 633: error = 0.7851917, gradient norm = 0.0000530
# [t-SNE] Iteration 634: error = 0.7851608, gradient norm = 0.0000620
# [t-SNE] Iteration 635: error = 0.7851303, gradient norm = 0.0001009
# [t-SNE] Iteration 636: error = 0.7851011, gradient norm = 0.0001762
# [t-SNE] Iteration 637: error = 0.7850735, gradient norm = 0.0002696
# [t-SNE] Iteration 638: error = 0.7850390, gradient norm = 0.0001843
# [t-SNE] Iteration 639: error = 0.7850059, gradient norm = 0.0001144
# [t-SNE] Iteration 640: error = 0.7849772, gradient norm = 0.0002072
# [t-SNE] Iteration 641: error = 0.7849430, gradient norm = 0.0000969
# [t-SNE] Iteration 642: error = 0.7849132, gradient norm = 0.0001605
# [t-SNE] Iteration 643: error = 0.7848812, gradient norm = 0.0001378
# [t-SNE] Iteration 644: error = 0.7848488, gradient norm = 0.0000893
# [t-SNE] Iteration 645: error = 0.7848189, gradient norm = 0.0001645
# [t-SNE] Iteration 646: error = 0.7847854, gradient norm = 0.0000813
# [t-SNE] Iteration 647: error = 0.7847537, gradient norm = 0.0001006
# [t-SNE] Iteration 648: error = 0.7847220, gradient norm = 0.0001380
# [t-SNE] Iteration 649: error = 0.7846877, gradient norm = 0.0000769
# [t-SNE] Iteration 650: error = 0.7846531, gradient norm = 0.0000828
# [t-SNE] Iteration 651: error = 0.7846169, gradient norm = 0.0001196
# [t-SNE] Iteration 652: error = 0.7845766, gradient norm = 0.0000880
# [t-SNE] Iteration 653: error = 0.7845341, gradient norm = 0.0000629
# [t-SNE] Iteration 654: error = 0.7844911, gradient norm = 0.0000950
# [t-SNE] Iteration 655: error = 0.7844478, gradient norm = 0.0001009
# [t-SNE] Iteration 656: error = 0.7844052, gradient norm = 0.0000742
# [t-SNE] Iteration 657: error = 0.7843649, gradient norm = 0.0000652
# [t-SNE] Iteration 658: error = 0.7843264, gradient norm = 0.0000823
# [t-SNE] Iteration 659: error = 0.7842885, gradient norm = 0.0000834
# [t-SNE] Iteration 660: error = 0.7842505, gradient norm = 0.0000665
# [t-SNE] Iteration 661: error = 0.7842126, gradient norm = 0.0000621
# [t-SNE] Iteration 662: error = 0.7841748, gradient norm = 0.0000720
# [t-SNE] Iteration 663: error = 0.7841370, gradient norm = 0.0000717
# [t-SNE] Iteration 664: error = 0.7840991, gradient norm = 0.0000665
# [t-SNE] Iteration 665: error = 0.7840617, gradient norm = 0.0000936
# [t-SNE] Iteration 666: error = 0.7840250, gradient norm = 0.0001535
# [t-SNE] Iteration 667: error = 0.7839895, gradient norm = 0.0002423
# [t-SNE] Iteration 668: error = 0.7839479, gradient norm = 0.0001979
# [t-SNE] Iteration 669: error = 0.7839025, gradient norm = 0.0001031
# [t-SNE] Iteration 670: error = 0.7838579, gradient norm = 0.0002072
# [t-SNE] Iteration 671: error = 0.7838036, gradient norm = 0.0000874
# [t-SNE] Iteration 672: error = 0.7837571, gradient norm = 0.0001778
# [t-SNE] Iteration 673: error = 0.7837107, gradient norm = 0.0001112
# [t-SNE] Iteration 674: error = 0.7836652, gradient norm = 0.0001634
# [t-SNE] Iteration 675: error = 0.7836165, gradient norm = 0.0000887
# [t-SNE] Iteration 676: error = 0.7835751, gradient norm = 0.0001260
# [t-SNE] Iteration 677: error = 0.7835363, gradient norm = 0.0000871
# [t-SNE] Iteration 678: error = 0.7834991, gradient norm = 0.0001191
# [t-SNE] Iteration 679: error = 0.7834582, gradient norm = 0.0000974
# [t-SNE] Iteration 680: error = 0.7834145, gradient norm = 0.0001148
# [t-SNE] Iteration 681: error = 0.7833675, gradient norm = 0.0000928
# [t-SNE] Iteration 682: error = 0.7833198, gradient norm = 0.0001028
# [t-SNE] Iteration 683: error = 0.7832699, gradient norm = 0.0000814
# [t-SNE] Iteration 684: error = 0.7832193, gradient norm = 0.0000920
# [t-SNE] Iteration 685: error = 0.7831671, gradient norm = 0.0000757
# [t-SNE] Iteration 686: error = 0.7831144, gradient norm = 0.0000847
# [t-SNE] Iteration 687: error = 0.7830606, gradient norm = 0.0000770
# [t-SNE] Iteration 688: error = 0.7830068, gradient norm = 0.0000863
# [t-SNE] Iteration 689: error = 0.7829542, gradient norm = 0.0001073
# [t-SNE] Iteration 690: error = 0.7829060, gradient norm = 0.0001401
# [t-SNE] Iteration 691: error = 0.7828648, gradient norm = 0.0001746
# [t-SNE] Iteration 692: error = 0.7828269, gradient norm = 0.0001496
# [t-SNE] Iteration 693: error = 0.7827897, gradient norm = 0.0000908
# [t-SNE] Iteration 694: error = 0.7827529, gradient norm = 0.0001016
# [t-SNE] Iteration 695: error = 0.7827144, gradient norm = 0.0001197
# [t-SNE] Iteration 696: error = 0.7826730, gradient norm = 0.0000768
# [t-SNE] Iteration 697: error = 0.7826316, gradient norm = 0.0000990
# [t-SNE] Iteration 698: error = 0.7825896, gradient norm = 0.0000929
# [t-SNE] Iteration 699: error = 0.7825471, gradient norm = 0.0000753
# [t-SNE] Iteration 700: error = 0.7825051, gradient norm = 0.0000953
# [t-SNE] Iteration 701: error = 0.7824628, gradient norm = 0.0000727
# [t-SNE] Iteration 702: error = 0.7824209, gradient norm = 0.0000872
# [t-SNE] Iteration 703: error = 0.7823779, gradient norm = 0.0000748
# [t-SNE] Iteration 704: error = 0.7823345, gradient norm = 0.0000810
# [t-SNE] Iteration 705: error = 0.7822902, gradient norm = 0.0000851
# [t-SNE] Iteration 706: error = 0.7822455, gradient norm = 0.0000957
# [t-SNE] Iteration 707: error = 0.7822002, gradient norm = 0.0001151
# ...
# [t-SNE] Iteration 766: error = 0.7769234, gradient norm = 0.0001695
# [t-SNE] Iteration 767: error = 0.7768397, gradient norm = 0.0001627
# [t-SNE] Iteration 768: error = 0.7767587, gradient norm = 0.0001724
# [t-SNE] Iteration 769: error = 0.7766796, gradient norm = 0.0001713
# [t-SNE] Iteration 770: error = 0.7766026, gradient norm = 0.0001372
# [t-SNE] Iteration 771: error = 0.7765294, gradient norm = 0.0001436
# [t-SNE] Iteration 772: error = 0.7764595, gradient norm = 0.0001577
# [t-SNE] Iteration 773: error = 0.7763922, gradient norm = 0.0001530
# [t-SNE] Iteration 774: error = 0.7763280, gradient norm = 0.0001098
# [t-SNE] Iteration 775: error = 0.7762688, gradient norm = 0.0001171
# [t-SNE] Iteration 776: error = 0.7762136, gradient norm = 0.0001350
# [t-SNE] Iteration 777: error = 0.7761607, gradient norm = 0.0000965
# [t-SNE] Iteration 778: error = 0.7761113, gradient norm = 0.0001056
# [t-SNE] Iteration 779: error = 0.7760638, gradient norm = 0.0001228
# [t-SNE] Iteration 780: error = 0.7760169, gradient norm = 0.0000881
# [t-SNE] Iteration 781: error = 0.7759719, gradient norm = 0.0001026
# [t-SNE] Iteration 782: error = 0.7759275, gradient norm = 0.0001051
# [t-SNE] Iteration 783: error = 0.7758835, gradient norm = 0.0000834
# [t-SNE] Iteration 784: error = 0.7758408, gradient norm = 0.0001053
# [t-SNE] Iteration 785: error = 0.7757977, gradient norm = 0.0000951
# [t-SNE] Iteration 786: error = 0.7757550, gradient norm = 0.0000867
# [t-SNE] Iteration 787: error = 0.7757130, gradient norm = 0.0000919
# [t-SNE] Iteration 788: error = 0.7756712, gradient norm = 0.0000927
# [t-SNE] Iteration 789: error = 0.7756297, gradient norm = 0.0000795
# [t-SNE] Iteration 790: error = 0.7755890, gradient norm = 0.0000880
# [t-SNE] Iteration 791: error = 0.7755486, gradient norm = 0.0000971
# [t-SNE] Iteration 792: error = 0.7755083, gradient norm = 0.0000979
# [t-SNE] Iteration 793: error = 0.7754682, gradient norm = 0.0001120
# [t-SNE] Iteration 794: error = 0.7754276, gradient norm = 0.0001046
# [t-SNE] Iteration 795: error = 0.7753871, gradient norm = 0.0000927
# [t-SNE] Iteration 796: error = 0.7753473, gradient norm = 0.0001232
# [t-SNE] Iteration 797: error = 0.7753074, gradient norm = 0.0001165
# [t-SNE] Iteration 798: error = 0.7752672, gradient norm = 0.0000871
# [t-SNE] Iteration 799: error = 0.7752282, gradient norm = 0.0000838
# [t-SNE] Iteration 800: error = 0.7751903, gradient norm = 0.0000969
# [t-SNE] Iteration 801: error = 0.7751524, gradient norm = 0.0000961
# [t-SNE] Iteration 802: error = 0.7751148, gradient norm = 0.0000765
# [t-SNE] Iteration 803: error = 0.7750782, gradient norm = 0.0000844
# [t-SNE] Iteration 804: error = 0.7750421, gradient norm = 0.0000929
# [t-SNE] Iteration 805: error = 0.7750061, gradient norm = 0.0000687
# [t-SNE] Iteration 806: error = 0.7749710, gradient norm = 0.0000850
# [t-SNE] Iteration 807: error = 0.7749361, gradient norm = 0.0000803
# [t-SNE] Iteration 808: error = 0.7749015, gradient norm = 0.0000677
# [t-SNE] Iteration 809: error = 0.7748677, gradient norm = 0.0000828
# [t-SNE] Iteration 810: error = 0.7748336, gradient norm = 0.0000695
# [t-SNE] Iteration 811: error = 0.7748001, gradient norm = 0.0000719
# [t-SNE] Iteration 812: error = 0.7747668, gradient norm = 0.0000754
# [t-SNE] Iteration 813: error = 0.7747333, gradient norm = 0.0000739
# [t-SNE] Iteration 814: error = 0.7747000, gradient norm = 0.0000661
# [t-SNE] Iteration 815: error = 0.7746670, gradient norm = 0.0000725
# [t-SNE] Iteration 816: error = 0.7746338, gradient norm = 0.0000725
# [t-SNE] Iteration 817: error = 0.7746005, gradient norm = 0.0000649
# [t-SNE] Iteration 818: error = 0.7745671, gradient norm = 0.0000651
# [t-SNE] Iteration 819: error = 0.7745336, gradient norm = 0.0000692
# [t-SNE] Iteration 820: error = 0.7744999, gradient norm = 0.0000740
# [t-SNE] Iteration 821: error = 0.7744659, gradient norm = 0.0000923
# [t-SNE] Iteration 822: error = 0.7744312, gradient norm = 0.0000850
# [t-SNE] Iteration 823: error = 0.7743957, gradient norm = 0.0000720
# [t-SNE] Iteration 824: error = 0.7743596, gradient norm = 0.0000722
# [t-SNE] Iteration 825: error = 0.7743223, gradient norm = 0.0000828
# [t-SNE] Iteration 826: error = 0.7742823, gradient norm = 0.0000823
# [t-SNE] Iteration 827: error = 0.7742387, gradient norm = 0.0000724
# [t-SNE] Iteration 828: error = 0.7741926, gradient norm = 0.0000875
# [t-SNE] Iteration 829: error = 0.7741457, gradient norm = 0.0001028
# [t-SNE] Iteration 830: error = 0.7740977, gradient norm = 0.0000919
# [t-SNE] Iteration 831: error = 0.7740533, gradient norm = 0.0000918
# [t-SNE] Iteration 832: error = 0.7740105, gradient norm = 0.0000906
# [t-SNE] Iteration 833: error = 0.7739678, gradient norm = 0.0000860
# [t-SNE] Iteration 834: error = 0.7739248, gradient norm = 0.0000901
# [t-SNE] Iteration 835: error = 0.7738812, gradient norm = 0.0000787
# [t-SNE] Iteration 836: error = 0.7738384, gradient norm = 0.0000793
# [t-SNE] Iteration 837: error = 0.7737954, gradient norm = 0.0000845
# [t-SNE] Iteration 838: error = 0.7737512, gradient norm = 0.0000849
# [t-SNE] Iteration 839: error = 0.7737057, gradient norm = 0.0000785
# [t-SNE] Iteration 840: error = 0.7736610, gradient norm = 0.0000813
# [t-SNE] Iteration 841: error = 0.7736193, gradient norm = 0.0000846
# [t-SNE] Iteration 842: error = 0.7735816, gradient norm = 0.0000868
# [t-SNE] Iteration 843: error = 0.7735456, gradient norm = 0.0001022
# [t-SNE] Iteration 844: error = 0.7735098, gradient norm = 0.0000972
# [t-SNE] Iteration 845: error = 0.7734745, gradient norm = 0.0000869
# [t-SNE] Iteration 846: error = 0.7734400, gradient norm = 0.0000749
# [t-SNE] Iteration 847: error = 0.7734054, gradient norm = 0.0000838
# [t-SNE] Iteration 848: error = 0.7733700, gradient norm = 0.0000880
# [t-SNE] Iteration 849: error = 0.7733350, gradient norm = 0.0000712
# [t-SNE] Iteration 850: error = 0.7733006, gradient norm = 0.0000759
# [t-SNE] Iteration 851: error = 0.7732658, gradient norm = 0.0000858
# [t-SNE] Iteration 852: error = 0.7732294, gradient norm = 0.0000792
# [t-SNE] Iteration 853: error = 0.7731905, gradient norm = 0.0000930
# [t-SNE] Iteration 854: error = 0.7731465, gradient norm = 0.0001076
# [t-SNE] Iteration 855: error = 0.7730942, gradient norm = 0.0001182
# [t-SNE] Iteration 856: error = 0.7730316, gradient norm = 0.0001365
# [t-SNE] Iteration 857: error = 0.7729598, gradient norm = 0.0001394
# [t-SNE] Iteration 858: error = 0.7728895, gradient norm = 0.0001273
# [t-SNE] Iteration 859: error = 0.7728327, gradient norm = 0.0001149
# [t-SNE] Iteration 860: error = 0.7727913, gradient norm = 0.0001131
# [t-SNE] Iteration 861: error = 0.7727590, gradient norm = 0.0001118
# [t-SNE] Iteration 862: error = 0.7727304, gradient norm = 0.0001146
# [t-SNE] Iteration 863: error = 0.7727021, gradient norm = 0.0001139
# [t-SNE] Iteration 864: error = 0.7726727, gradient norm = 0.0001102
# [t-SNE] Iteration 865: error = 0.7726417, gradient norm = 0.0001086
# [t-SNE] Iteration 866: error = 0.7726097, gradient norm = 0.0001050
# [t-SNE] Iteration 867: error = 0.7725771, gradient norm = 0.0000985
# [t-SNE] Iteration 868: error = 0.7725448, gradient norm = 0.0000883
# [t-SNE] Iteration 869: error = 0.7725132, gradient norm = 0.0000849
# [t-SNE] Iteration 870: error = 0.7724826, gradient norm = 0.0000823
# [t-SNE] Iteration 871: error = 0.7724529, gradient norm = 0.0000750
# [t-SNE] Iteration 872: error = 0.7724242, gradient norm = 0.0000677
# [t-SNE] Iteration 873: error = 0.7723964, gradient norm = 0.0000670
# [t-SNE] Iteration 874: error = 0.7723693, gradient norm = 0.0000699
# [t-SNE] Iteration 875: error = 0.7723428, gradient norm = 0.0000732
# [t-SNE] Iteration 876: error = 0.7723165, gradient norm = 0.0000682
# [t-SNE] Iteration 877: error = 0.7722905, gradient norm = 0.0000593
# [t-SNE] Iteration 878: error = 0.7722649, gradient norm = 0.0000644
# [t-SNE] Iteration 879: error = 0.7722394, gradient norm = 0.0000685
# [t-SNE] Iteration 880: error = 0.7722141, gradient norm = 0.0000700
# [t-SNE] Iteration 881: error = 0.7721888, gradient norm = 0.0000590
# [t-SNE] Iteration 882: error = 0.7721637, gradient norm = 0.0000596
# [t-SNE] Iteration 883: error = 0.7721390, gradient norm = 0.0000656
# [t-SNE] Iteration 884: error = 0.7721143, gradient norm = 0.0000659
# [t-SNE] Iteration 885: error = 0.7720895, gradient norm = 0.0000563
# [t-SNE] Iteration 886: error = 0.7720650, gradient norm = 0.0000593
# [t-SNE] Iteration 887: error = 0.7720404, gradient norm = 0.0000669
# [t-SNE] Iteration 888: error = 0.7720149, gradient norm = 0.0000674
# [t-SNE] Iteration 889: error = 0.7719878, gradient norm = 0.0000683
# [t-SNE] Iteration 890: error = 0.7719565, gradient norm = 0.0000750
# [t-SNE] Iteration 891: error = 0.7719208, gradient norm = 0.0001021
# [t-SNE] Iteration 892: error = 0.7718891, gradient norm = 0.0001383
# [t-SNE] Iteration 893: error = 0.7718596, gradient norm = 0.0001085
# [t-SNE] Iteration 894: error = 0.7718370, gradient norm = 0.0000988
# [t-SNE] Iteration 895: error = 0.7718175, gradient norm = 0.0001067
# [t-SNE] Iteration 896: error = 0.7717961, gradient norm = 0.0001085
# [t-SNE] Iteration 897: error = 0.7717695, gradient norm = 0.0000889
# [t-SNE] Iteration 898: error = 0.7717437, gradient norm = 0.0000811
# [t-SNE] Iteration 899: error = 0.7717202, gradient norm = 0.0000786
# [t-SNE] Iteration 900: error = 0.7716982, gradient norm = 0.0000736
# [t-SNE] Iteration 901: error = 0.7716769, gradient norm = 0.0000697
# [t-SNE] Iteration 902: error = 0.7716556, gradient norm = 0.0000724
# [t-SNE] Iteration 903: error = 0.7716343, gradient norm = 0.0000742
# [t-SNE] Iteration 904: error = 0.7716125, gradient norm = 0.0000719
# [t-SNE] Iteration 905: error = 0.7715899, gradient norm = 0.0000712
# [t-SNE] Iteration 906: error = 0.7715667, gradient norm = 0.0000687
# [t-SNE] Iteration 907: error = 0.7715432, gradient norm = 0.0000661
# [t-SNE] Iteration 908: error = 0.7715196, gradient norm = 0.0000575
# [t-SNE] Iteration 909: error = 0.7714958, gradient norm = 0.0000580
# [t-SNE] Iteration 910: error = 0.7714714, gradient norm = 0.0000640
# [t-SNE] Iteration 911: error = 0.7714459, gradient norm = 0.0000673
# [t-SNE] Iteration 912: error = 0.7714190, gradient norm = 0.0000658
# [t-SNE] Iteration 913: error = 0.7713902, gradient norm = 0.0000696
# [t-SNE] Iteration 914: error = 0.7713591, gradient norm = 0.0000781
# [t-SNE] Iteration 915: error = 0.7713239, gradient norm = 0.0000910
# [t-SNE] Iteration 916: error = 0.7712821, gradient norm = 0.0001036
# [t-SNE] Iteration 917: error = 0.7712296, gradient norm = 0.0001236
# [t-SNE] Iteration 918: error = 0.7711610, gradient norm = 0.0001477
# [t-SNE] Iteration 919: error = 0.7710763, gradient norm = 0.0001573
# [t-SNE] Iteration 920: error = 0.7710037, gradient norm = 0.0001107
# [t-SNE] Iteration 921: error = 0.7709991, gradient norm = 0.0002106
# [t-SNE] Iteration 922: error = 0.7709692, gradient norm = 0.0001990
# [t-SNE] Iteration 923: error = 0.7709225, gradient norm = 0.0001235
# [t-SNE] Iteration 924: error = 0.7709041, gradient norm = 0.0001846
# [t-SNE] Iteration 925: error = 0.7708696, gradient norm = 0.0001779
# [t-SNE] Iteration 926: error = 0.7708235, gradient norm = 0.0001170
# [t-SNE] Iteration 927: error = 0.7707911, gradient norm = 0.0000866
# [t-SNE] Iteration 928: error = 0.7707709, gradient norm = 0.0000996
# [t-SNE] Iteration 929: error = 0.7707522, gradient norm = 0.0001160
# [t-SNE] Iteration 930: error = 0.7707293, gradient norm = 0.0001173
# [t-SNE] Iteration 931: error = 0.7707020, gradient norm = 0.0001038
# [t-SNE] Iteration 932: error = 0.7706739, gradient norm = 0.0000884
# [t-SNE] Iteration 933: error = 0.7706486, gradient norm = 0.0000854
# [t-SNE] Iteration 934: error = 0.7706263, gradient norm = 0.0000935
# [t-SNE] Iteration 935: error = 0.7706045, gradient norm = 0.0001007
# [t-SNE] Iteration 936: error = 0.7705811, gradient norm = 0.0000922
# [t-SNE] Iteration 937: error = 0.7705574, gradient norm = 0.0000870
# [t-SNE] Iteration 938: error = 0.7705334, gradient norm = 0.0000809
# [t-SNE] Iteration 939: error = 0.7705093, gradient norm = 0.0000653
# [t-SNE] Iteration 940: error = 0.7704871, gradient norm = 0.0000726
# [t-SNE] Iteration 941: error = 0.7704653, gradient norm = 0.0000733
# [t-SNE] Iteration 942: error = 0.7704432, gradient norm = 0.0000714
# [t-SNE] Iteration 943: error = 0.7704213, gradient norm = 0.0000728
# [t-SNE] Iteration 944: error = 0.7703990, gradient norm = 0.0000664
# [t-SNE] Iteration 945: error = 0.7703773, gradient norm = 0.0000637
# [t-SNE] Iteration 946: error = 0.7703558, gradient norm = 0.0000594
# [t-SNE] Iteration 947: error = 0.7703349, gradient norm = 0.0000636
# [t-SNE] Iteration 948: error = 0.7703137, gradient norm = 0.0000642
# [t-SNE] Iteration 949: error = 0.7702925, gradient norm = 0.0000630
# [t-SNE] Iteration 950: error = 0.7702709, gradient norm = 0.0000622
# [t-SNE] Iteration 951: error = 0.7702494, gradient norm = 0.0000636
# [t-SNE] Iteration 952: error = 0.7702274, gradient norm = 0.0000614
# [t-SNE] Iteration 953: error = 0.7702055, gradient norm = 0.0000602
# [t-SNE] Iteration 954: error = 0.7701836, gradient norm = 0.0000603
# [t-SNE] Iteration 955: error = 0.7701616, gradient norm = 0.0000627
# [t-SNE] Iteration 956: error = 0.7701394, gradient norm = 0.0000635
# [t-SNE] Iteration 957: error = 0.7701169, gradient norm = 0.0000616
# [t-SNE] Iteration 958: error = 0.7700941, gradient norm = 0.0000615
# [t-SNE] Iteration 959: error = 0.7700712, gradient norm = 0.0000622
# [t-SNE] Iteration 960: error = 0.7700479, gradient norm = 0.0000621
# [t-SNE] Iteration 961: error = 0.7700244, gradient norm = 0.0000622
# [t-SNE] Iteration 962: error = 0.7700005, gradient norm = 0.0000630
# [t-SNE] Iteration 963: error = 0.7699760, gradient norm = 0.0000634
# [t-SNE] Iteration 964: error = 0.7699512, gradient norm = 0.0000623
# [t-SNE] Iteration 965: error = 0.7699258, gradient norm = 0.0000647
# [t-SNE] Iteration 966: error = 0.7698998, gradient norm = 0.0000652
# [t-SNE] Iteration 967: error = 0.7698731, gradient norm = 0.0000652
# [t-SNE] Iteration 968: error = 0.7698456, gradient norm = 0.0000664
# [t-SNE] Iteration 969: error = 0.7698173, gradient norm = 0.0000686
# [t-SNE] Iteration 970: error = 0.7697879, gradient norm = 0.0000724
# [t-SNE] Iteration 971: error = 0.7697571, gradient norm = 0.0000748
# [t-SNE] Iteration 972: error = 0.7697246, gradient norm = 0.0000764
# [t-SNE] Iteration 973: error = 0.7696900, gradient norm = 0.0000796
# [t-SNE] Iteration 974: error = 0.7696532, gradient norm = 0.0000842
# [t-SNE] Iteration 975: error = 0.7696145, gradient norm = 0.0000890
# [t-SNE] Iteration 976: error = 0.7695760, gradient norm = 0.0000940
# [t-SNE] Iteration 977: error = 0.7695414, gradient norm = 0.0001054
# [t-SNE] Iteration 978: error = 0.7695119, gradient norm = 0.0001193
# [t-SNE] Iteration 979: error = 0.7694832, gradient norm = 0.0001224
# [t-SNE] Iteration 980: error = 0.7694525, gradient norm = 0.0001103
# [t-SNE] Iteration 981: error = 0.7694214, gradient norm = 0.0000892
# [t-SNE] Iteration 982: error = 0.7693931, gradient norm = 0.0000715
# [t-SNE] Iteration 983: error = 0.7693683, gradient norm = 0.0000643
# [t-SNE] Iteration 984: error = 0.7693458, gradient norm = 0.0000639
# [t-SNE] Iteration 985: error = 0.7693245, gradient norm = 0.0000617
# [t-SNE] Iteration 986: error = 0.7693043, gradient norm = 0.0000565
# [t-SNE] Iteration 987: error = 0.7692850, gradient norm = 0.0000564
# [t-SNE] Iteration 988: error = 0.7692662, gradient norm = 0.0000576
# [t-SNE] Iteration 989: error = 0.7692477, gradient norm = 0.0000579
# [t-SNE] Iteration 990: error = 0.7692294, gradient norm = 0.0000553
# [t-SNE] Iteration 991: error = 0.7692112, gradient norm = 0.0000546
# [t-SNE] Iteration 992: error = 0.7691930, gradient norm = 0.0000540
# [t-SNE] Iteration 993: error = 0.7691751, gradient norm = 0.0000514
# [t-SNE] Iteration 994: error = 0.7691573, gradient norm = 0.0000525
# [t-SNE] Iteration 995: error = 0.7691397, gradient norm = 0.0000509
# [t-SNE] Iteration 996: error = 0.7691223, gradient norm = 0.0000475
# [t-SNE] Iteration 997: error = 0.7691052, gradient norm = 0.0000481
# [t-SNE] Iteration 998: error = 0.7690882, gradient norm = 0.0000452
# [t-SNE] Iteration 999: error = 0.7690715, gradient norm = 0.0000444
# [t-SNE] Iteration 1000: error = 0.7690550, gradient norm = 0.0000443
